# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\HP\Downloads\Support_tickets.csv")
df
# Out:
#         ticket_id day_of_week  day_of_week_num  company_id company_size  \
# 0      1000000000         Wed                3      100015        Small
# 1      1000000001         Sat                6      100023        Small
# 2      1000000002         Mon                1      100012        Small
# 3      1000000003         Wed                3      100003        Small
# 4      1000000004         Mon                1      100019        Small
# ...           ...         ...              ...         ...          ...
# 49995  1000049995         Wed                3      100021       Medium
# 49996  1000049996         Fri                5      100010        Large
# 49997  1000049997         Tue                2      100002        Large
# 49998  1000049998         Wed                3      100022       Medium
# 49999  1000049999         Fri                5      100017        Small
#
#        company_size_cat    industry  industry_cat customer_tier  \
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#         ticket_id day_of_week  day_of_week_num  company_id company_size  \
# 0      1000000000         Wed                3      100015        Small
# 1      1000000001         Sat                6      100023        Small
# 2      1000000002         Mon                1      100012        Small
# 3      1000000003         Wed                3      100003        Small
# 4      1000000004         Mon                1      100019        Small
# ...           ...         ...              ...         ...          ...
# 49995  1000049995         Wed                3      100021       Medium
# 49996  1000049996         Fri                5      100010        Large
# 49997  1000049997         Tue                2      100002        Large
# 49998  1000049998         Wed                3      100022       Medium
# 49999  1000049999         Fri                5      100017        Small
#
#        company_size_cat    industry  industry_cat customer_tier  \
# ...

# %%
df = df.reset_index(drop=True)
df
# Out:
#         ticket_id day_of_week  day_of_week_num  company_id company_size  \
# 0      1000000000         Wed                3      100015        Small
# 1      1000000001         Sat                6      100023        Small
# 2      1000000002         Mon                1      100012        Small
# 3      1000000003         Wed                3      100003        Small
# 4      1000000004         Mon                1      100019        Small
# ...           ...         ...              ...         ...          ...
# 49995  1000049995         Wed                3      100021       Medium
# 49996  1000049996         Fri                5      100010        Large
# 49997  1000049997         Tue                2      100002        Large
# 49998  1000049998         Wed                3      100022       Medium
# 49999  1000049999         Fri                5      100017        Small
#
#        company_size_cat    industry  industry_cat customer_tier  \
# ...

# %%
print(df)
# Out:
#         ticket_id day_of_week  day_of_week_num  company_id company_size  \
# 0      1000000000         Wed                3      100015        Small
# 1      1000000001         Sat                6      100023        Small
# 2      1000000002         Mon                1      100012        Small
# 3      1000000003         Wed                3      100003        Small
# 4      1000000004         Mon                1      100019        Small
# ...           ...         ...              ...         ...          ...
# 49995  1000049995         Wed                3      100021       Medium
# 49996  1000049996         Fri                5      100010        Large
# 49997  1000049997         Tue                2      100002        Large
# 49998  1000049998         Wed                3      100022       Medium
# 49999  1000049999         Fri                5      100017        Small
#
#        company_size_cat    industry  industry_cat customer_tier  \
# ...
